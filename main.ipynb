# %%
from main import bdba

# %%
#convert list to dataframe
import pandas as pd
df = pd.DataFrame(bdba) #convert list to a dataframe
print(f'df dtype is {type(df)}') #confirm conversion
print(f'df shape is {df.shape}') #assess number of rows and columns
df.to_excel('bdba.xlsx', index=False) #create excel workbook to view data strings
df.head()
# Out:
# df dtype is <class 'pandas.core.frame.DataFrame'>
# df shape is (19, 15)
#         lib                     objects version  \
# 0       acl           [libacl.so.1.1.0]    None
# 1     acpid                     [acpid]  2.0.23
# 2       apr         [libapr-1.so.0.5.2]   1.5.2
# 3  apr-util     [libaprutil-1.so.0.5.4]   1.5.4
# 4     avahi  [libavahi-client.so.3.2.9]     0.6
#
#                                     extended-objects  \
# 0  [{'name': 'libacl.so.1.1.0', 'fullpath': ['53c...
# 1  [{'name': 'acpid', 'fullpath': ['53c7fe59_unbu...
# 2  [{'name': 'libapr-1.so.0.5.2', 'fullpath': ['5...
# 3  [{'name': 'libaprutil-1.so.0.5.4', 'fullpath':...
# 4  [{'name': 'libavahi-client.so.3.2.9', 'fullpat...
#
#                                                vulns  known_component  \
# 0  [{'vuln': {'cve': 'CVE-2009-4411', 'summary': ...             True
# 1  [{'vuln': {'cve': 'CVE-2009-0798', 'summary': ...             True
# 2  [{'vuln': {'cve': 'CVE-2017-12613', 'summary':...             True
# 3  [{'vuln': {'cve': 'CVE-2009-0023', 'summary': ...             True
# 4  [{'vuln': {'cve': 'CVE-2021-3468', 'summary': ...             True
#
#                                                  cpe  \
# 0         [cpe:/a:acl:acl:, cpe:/a:acl_project:acl:]
# 1  [cpe:/a:tim_hockin:acpid:2.0.23, cpe:/a:tedfel...
# 2             [cpe:/a:apache:portable_runtime:1.5.2]
# 3                     [cpe:/a:apache:apr-util:1.5.4]
# 4                           [cpe:/a:avahi:avahi:0.6]
#
#                         tags                                   homepage  \
# 0                      [acl]  https://savannah.nongnu.org/projects/acl/
# 1  [powermanagement, system]   https://sourceforge.net/projects/acpid2/
# 2                [framework]                    https://apr.apache.org/
# 3                [framework]                    https://apr.apache.org/
# 4                 [protocol]                          https://avahi.org
#
#   latest-version codetype                                      coverity_scan  \
# 0          2.3.1   native                                               None
# 1         2.0.33   native                                               None
# 2          1.7.0   native                                               None
# 3          1.6.1   native                                               None
# 4            0.8   native  {'id': 3652, 'name': 'avahi', 'language': 'C/C...
#
#                                              license  \
# 0  {'name': 'LGPL', 'url': 'https://www.gnu.org/c...
# 1  {'name': 'GPL', 'url': 'https://www.gnu.org/li...
# 2  {'name': 'Apache', 'url': 'https://www.apache....
# 3  {'name': 'Apache', 'url': 'https://www.apache....
# 4  {'name': 'LGPL', 'url': 'https://www.gnu.org/c...
#
#                                    vuln-count vendor
# 0   {'total': 1, 'exact': 0, 'historical': 1}    NaN
# 1   {'total': 4, 'exact': 0, 'historical': 4}    NaN
# 2   {'total': 6, 'exact': 1, 'historical': 5}    NaN
# 3   {'total': 6, 'exact': 0, 'historical': 6}    NaN
# 4  {'total': 13, 'exact': 7, 'historical': 6}    NaN

# %%
## Question 1:
## Find all versionless components (lib where version is null)
df_null = df[df['version'].isnull()]
df_null
# Out:
#          lib                                            objects version  \
# 0        acl                                  [libacl.so.1.1.0]    None
# 9      boost  [libosiris.so, libboost_filesystem.so.1.54.0, ...    None
# 14  cracklib                                [libcrack.so.2.9.0]    None
# 15    cronie                                          [crontab]    None
#
#                                      extended-objects  \
# 0   [{'name': 'libacl.so.1.1.0', 'fullpath': ['53c...
# 9   [{'name': 'libosiris.so', 'fullpath': ['53c7fe...
# 14  [{'name': 'libcrack.so.2.9.0', 'fullpath': ['5...
# 15  [{'name': 'crontab', 'fullpath': ['53c7fe59_un...
#
#                                                 vulns  known_component  \
# 0   [{'vuln': {'cve': 'CVE-2009-4411', 'summary': ...             True
# 9   [{'vuln': {'cve': 'CVE-2008-0171', 'summary': ...             True
# 14  [{'vuln': {'cve': 'CVE-1999-1140', 'summary': ...             True
# 15  [{'vuln': {'cve': 'CVE-2010-0424', 'summary': ...             True
#
#                                            cpe               tags  \
# 0   [cpe:/a:acl:acl:, cpe:/a:acl_project:acl:]              [acl]
# 9                        [cpe:/a:boost:boost:]                 []
# 14         [cpe:/a:cracklib_project:cracklib:]         [password]
# 15               [cpe:/a:fedorahosted:cronie:]  [system, utility]
#
#                                      homepage latest-version codetype  \
# 0   https://savannah.nongnu.org/projects/acl/          2.3.1   native
# 9                      https://www.boost.org/         1.78.0   native
# 14       https://github.com/cracklib/cracklib          2.9.7   native
# 15    https://github.com/cronie-crond/cronie/          1.6.1   native
#
#                                         coverity_scan  \
# 0                                                None
# 9   {'id': 989, 'name': 'boost', 'language': 'C/C+...
# 14  {'id': 17800, 'name': 'cracklib/cracklib', 'la...
# 15                                               None
#
#                                               license  \
# 0   {'name': 'LGPL', 'url': 'https://www.gnu.org/c...
# 9   {'name': 'Boost', 'url': 'http://www.boost.org...
# 14  {'name': 'LGPL', 'url': 'https://www.gnu.org/c...
# 15  {'name': 'BSD', 'url': 'http://www.linfo.org/b...
#
#                                    vuln-count vendor
# 0   {'total': 1, 'exact': 0, 'historical': 1}    NaN
# 9   {'total': 3, 'exact': 0, 'historical': 3}    NaN
# 14  {'total': 2, 'exact': 0, 'historical': 2}    NaN
# 15  {'total': 2, 'exact': 0, 'historical': 2}    NaN

# %%
## Question 2:
## Print a list of all unique vendor names
df.vendor.unique()
# Out:
# array([nan, 'bzip', 'gnu'], dtype=object)

# %%
## Question 3:
## Find all components with vulns with cvss score > 8
## (Structure [vulns(list of dicts)]{'vuln'}('cvss')
df_vulns = df.copy()  #duplicate original df to work on it
df_vulns.insert(5, "cvss3_score", df_vulns['vulns'].apply(lambda x: x[0]['vuln']['cvss3_score'])) #grab the cvss3_score from the first vuln in the list
df_vulns['cvss3_score'] = df_vulns['cvss3_score'].astype(float) #convert to float because existing value is a string
df_vulns_high = df_vulns[df_vulns['cvss3_score'] > 8] #filter for cvss3_score > 8
df_vulns_high.head()
# Out:
#        lib                             objects version  \
# 10   bzip2  [libbz2.so.0.0.0, libbz2.so.0.0.0]   1.0.6
# 11  c-ares                 [libcares.so.2.1.0]  1.10.0
#
#                                      extended-objects  \
# 10  [{'name': 'libbz2.so.0.0.0', 'fullpath': ['53c...
# 11  [{'name': 'libcares.so.2.1.0', 'fullpath': ['5...
#
#                                                 vulns  cvss3_score  \
# 10  [{'vuln': {'cve': 'CVE-2019-12900', 'summary':...          9.8
# 11  [{'vuln': {'cve': 'CVE-2016-5180', 'summary': ...          9.8
#
#     known_component                                    cpe           tags  \
# 10             True              [cpe:/a:bzip:bzip2:1.0.6]  [compression]
# 11             True  [cpe:/a:c-ares_project:c-ares:1.10.0]     [protocol]
#
#                          homepage latest-version codetype  \
# 10  https://sourceware.org/bzip2/          1.0.8   native
# 11            https://c-ares.org/         1.18.1   native
#
#                                         coverity_scan  \
# 10                                               None
# 11  {'id': 3018, 'name': 'c-ares', 'language': 'C/...
#
#                                               license  \
# 10  {'name': 'BSD', 'url': 'http://www.linfo.org/b...
# 11  {'name': 'MIT', 'url': 'https://opensource.org...
#
#                                     vuln-count vendor
# 10  {'total': 10, 'exact': 2, 'historical': 8}   bzip
# 11   {'total': 7, 'exact': 4, 'historical': 3}    NaN
